# %%
import pandas as pd
df = pd.read_csv('classification_data.csv')

# %%
df.head()
# Out:
#                  client_id  avg_session_duration            browser  \
# 0   GA889580594.1590808701            158.000000  Internet Explorer
# 1   GA616880682.1596545776              7.000000             Chrome
# 2   GA946056279.1598894360            261.333333             Chrome
# 3   GA609176977.1586186638            126.384615             Chrome
# 4  GA1964696600.1602347357             79.000000             Chrome
#
#   browser_version                campaign  hits  day_of_week  day  \
# 0            11.0                   Other    18            5   29
# 1     79.0.3945.0                   Other     7            2    4
# 2   84.0.4147.135                   Other   103            4   31
# 3    83.0.4103.96  Shoes Sale-Display Ads    42            6   30
# 4   85.0.4183.127                   Other    13            6   10
#
#   device_category  entrances  ...  page_depth  page_views  \
# 0          tablet          1  ...          18          18
# ...

# %%
for col in df.columns :
    print(col)
# Out:
# client_id
# avg_session_duration
# browser
# browser_version
# hits
# day_of_week
# day
# entrances
# events_per_session
# exits
# hour
# organic_search
# os
# page_depth
# page_views
# page_views_per_session
# sessions
# events
# unique_events
# week
# shopping_stage
# frequency

# %%
print(df['campaign'].unique())
print(df['device_category'].unique())
print(df['social_network'].unique())
df = df.drop(['campaign','device_category','social_network'],axis = 1)
print(df.max() - df.min())
# Out:
# ['Other' 'Shoes Sale-Display Ads' 'Search Ads-Summer-Shoes'
#  'Dynamic Search Ads-Shoes'
#  'Brand Awareness and Reach-Make Life Indoors-Display Ads'
#  'Father day shoes sale-Display ads'
#  'Winter Collection 2020-Display Camapign' 'Father Day Shoe Sale'
#  'Display ADS - RE + Custom AU']
# ['tablet' 'desktop' 'mobile']
# ['Other' 'Facebook' 'Instagram Stories' 'Slashdot' 'reddit' 'Twitter'
#  'LinkedIn' 'Yelp' 'Pinterest' 'Diigo' 'Tumblr' 'Pocket' 'Quora']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
# ...
